# %%
word='grail'
sent='a scratch'

print(word[0])
print(sent[0])
print(word[0:3])
print(sent[-1])
print(sent[-9:-8])
print(sent[0:-8])
print(sent[2:-1])
print(sent[-7:-1])

s_len=len(sent)
print(s_len)

print(sent[2:s_len])

print(word[0:3])
print(word[:3])
print(sent[2:len(sent)])
print(sent[2:])
print(sent[:])
print(sent[::2])
# Out:
# g
# a
# gra
# h
# a
# a
# scratc
# scratc
# 9
# scratch
# gra
# gra
# scratch
# scratch
# a scratch
# asrth

# %%
d1='40°'
m1="46'"
s1='52.837'
u1='N'

d2='73°'
m2="58'"
s2='26.302"'
u2='W'

coords=''.join([d1,m2,s2,u1,d2,m2,s2,u2])
print(coords)

multi_str="""Guard:What? Ridden on a horse?
King Arthur:Yes!
Guard:You're using coconuts!
King Arthur:What?
Guard:Yov've got ...coconut[s] and you're bangin''em together.
"""
print(multi_str)

multi_str_split=multi_str.splitlines()
print(multi_str_split)

guard=multi_str_split[::2]
print(guard)

guard=multi_str.replace("Guard:","").splitlines()[::2]
print(guard)
# Out:
# 40°58'26.302"N73°58'26.302"W
# Guard:What? Ridden on a horse?
# King Arthur:Yes!
# Guard:You're using coconuts!
# King Arthur:What?
# Guard:Yov've got ...coconut[s] and you're bangin''em together.
#
# ['Guard:What? Ridden on a horse?', 'King Arthur:Yes!', "Guard:You're using coconuts!", 'King Arthur:What?', "Guard:Yov've got ...coconut[s] and you're bangin''em together."]
# ['Guard:What? Ridden on a horse?', "Guard:You're using coconuts!", "Guard:Yov've got ...coconut[s] and you're bangin''em together."]
# ['What? Ridden on a horse?', "You're using coconuts!", "Yov've got ...coconut[s] and you're bangin''em together."]

# %%
var='flesh wound'
s="It's just a {}!"
print(s.format(var))
print(s.format('scratch'))

s="""Black Knight: 'Tis but a {0}.
King Arthur: A {0}? Your arm's off!
"""
print(s.format('scratch'))

s='Hayden Planetarium Coordinates:{lat},{lon}'
print(s.format(lat='40.7815°N', lon='73.9733°W'))

print('Some igits of pi:{}'.format(3.14159265359))
print("In 2005, Lu Chao of China recited{:,} digits of pi".format(67890))

print("I remember {0:4} or {0:4%} of what Lu Chao recited".format(7/67890))

print("My ID number is {0:05d}".format(42))

s='I only know %d digits of pi' %7
print(s)

print('Some digits of %(cont)s: %(value).2f'%{'cont':'e','value':2.718})

var='flesh wound'
s=f"It's just a {var}!"
print(s)

lat='40.7815°N'
lon='73.9733°W'
s=f'Hayden Planetarium Coordinates:{lat},{lon}'
print(s)
# Out:
# It's just a flesh wound!
# It's just a scratch!
# Black Knight: 'Tis but a scratch.
# King Arthur: A scratch? Your arm's off!
#
# Hayden Planetarium Coordinates:40.7815°N,73.9733°W
# Some igits of pi:3.14159265359
# In 2005, Lu Chao of China recited67,890 digits of pi
# I remember 0.00010310796877301516 or 0.010311% of what Lu Chao recited
# My ID number is 00042
# I only know 7 digits of pi
# Some digits of e: 2.72
# It's just a flesh wound!
# Hayden Planetarium Coordinates:40.7815°N,73.9733°W

# %%
import re
tele_num='1234567890'

m=re.match(pattern='\d\d\d\d\d\d\d\d\d\d',string=tele_num)
print(type(m))
print(m)
print(bool(m))
if m:
    print('match')
else:
    print('no match')
print(m.start())
print(m.end())
print(m.span())
print(m.group())

tele_num_spaces='123 456 7890'
m=re.match(pattern='\d{10}',string=tele_num_spaces)
print(m)

if m:
    print('match')
else:
    print('no match')

p='\d{3}\s?\d{3}\s?\d{4}'
m=re.match(pattern=p,string=tele_num_spaces)
print(m)

tele_num_space_paren_dash='(123) 456-7890'
p='\(?\d{3}\)?\s?\d{3}\s?-?\d{4}'
print(m)

cnty_tele_num_space_paren_dash= '+1 (123) 456-7890'
p='\+?1\s?\(?\d{3}\)?\s?\d{3}\s?-?\d{4}'
m=re.match(pattern=p,string=cnty_tele_num_space_paren_dash)
print(m)

p=re.compile('\d{10}')
s='1234567890'
m=p.match(s)
print(m)
# Out:
# <class 're.Match'>
# <re.Match object; span=(0, 10), match='1234567890'>
# True
# match
# 0
# 10
# (0, 10)
# 1234567890
# None
# no match
# <re.Match object; span=(0, 12), match='123 456 7890'>
# <re.Match object; span=(0, 12), match='123 456 7890'>
# <re.Match object; span=(0, 17), match='+1 (123) 456-7890'>
# <re.Match object; span=(0, 10), match='1234567890'>
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:18: SyntaxWarning: invalid escape sequence '\d'
# <>:26: SyntaxWarning: invalid escape sequence '\d'
# <>:31: SyntaxWarning: invalid escape sequence '\('
# <>:35: SyntaxWarning: invalid escape sequence '\+'
# <>:39: SyntaxWarning: invalid escape sequence '\d'
# <>:4: SyntaxWarning: invalid escape sequence '\d'
# <>:18: SyntaxWarning: invalid escape sequence '\d'
# <>:26: SyntaxWarning: invalid escape sequence '\d'
# <>:31: SyntaxWarning: invalid escape sequence '\('
# <>:35: SyntaxWarning: invalid escape sequence '\+'
# <>:39: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\dasom\AppData\Local\Temp\ipykernel_21980\2130004449.py:4: SyntaxWarning: invalid escape sequence '\d'
#   m=re.match(pattern='\d\d\d\d\d\d\d\d\d\d',string=tele_num)
# C:\Users\dasom\AppData\Local\Temp\ipykernel_21980\2130004449.py:18: SyntaxWarning: invalid escape sequence '\d'
#   m=re.match(pattern='\d{10}',string=tele_num_spaces)
# C:\Users\dasom\AppData\Local\Temp\ipykernel_21980\2130004449.py:26: SyntaxWarning: invalid escape sequence '\d'
#   p='\d{3}\s?\d{3}\s?\d{4}'
# C:\Users\dasom\AppData\Local\Temp\ipykernel_21980\2130004449.py:31: SyntaxWarning: invalid escape sequence '\('
#   p='\(?\d{3}\)?\s?\d{3}\s?-?\d{4}'
# C:\Users\dasom\AppData\Local\Temp\ipykernel_21980\2130004449.py:35: SyntaxWarning: invalid escape sequence '\+'
#   p='\+?1\s?\(?\d{3}\)?\s?\d{3}\s?-?\d{4}'
# C:\Users\dasom\AppData\Local\Temp\ipykernel_21980\2130004449.py:39: SyntaxWarning: invalid escape sequence '\d'
#   p=re.compile('\d{10}')
